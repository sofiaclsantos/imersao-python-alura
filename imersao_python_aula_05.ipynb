# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiaclsantos/imersao-python-alura/blob/main/imersao_python_aula_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 05

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from prophet import Prophet # biblioteca de séries temporais

# %%
# criar uma tabela com dados dos ultimos 4 anos para uma acao especifica

dados = yf.download("JNJ", start="2020-01-01", end="2023-12-31", progress=False)
dados = dados.reset_index()
dados
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2020-01-02  145.869995  146.020004  145.080002  145.970001  130.099121
# 1    2020-01-03  143.500000  145.369995  143.000000  144.279999  128.592865
# 2    2020-01-06  144.000000  144.199997  142.850006  144.100006  128.432419
# 3    2020-01-07  144.009995  145.449997  141.380005  144.979996  129.216736
# 4    2020-01-08  144.869995  145.979996  143.699997  144.960007  129.198959
# ...         ...         ...         ...         ...         ...         ...
# 1001 2023-12-22  155.250000  156.529999  155.020004  155.460007  154.288544
# 1002 2023-12-26  155.000000  156.350006  154.850006  156.139999  154.963409
# 1003 2023-12-27  155.500000  156.520004  155.419998  156.350006  155.171844
# 1004 2023-12-28  156.000000  157.240005  155.990005  156.580002  155.400101
# 1005 2023-12-29  156.509995  156.899994  155.979996  156.740005  155.558899
#
#        Volume
# 0     5777000
# 1     5752400
# ...

# %%
# divisao em 2 tabelas de datas de treino (ate final do primeiro semestre de 2023) e teste (segundo semestre de 2023)

dados_treino = dados[dados['Date'] < '2023-07-31']
dados_teste = dados[dados['Date'] >= '2023-07-31']

# %%
# preparando dados
dados_prophet_treino = dados_treino[['Date', 'Close']].rename(columns={'Date' : 'ds', 'Close': 'y'})
dados_prophet_treino
# Out:
#             ds           y
# 0   2020-01-02  145.970001
# 1   2020-01-03  144.279999
# 2   2020-01-06  144.100006
# 3   2020-01-07  144.979996
# 4   2020-01-08  144.960007
# ..         ...         ...
# 894 2023-07-24  171.080002
# 895 2023-07-25  172.389999
# 896 2023-07-26  172.720001
# 897 2023-07-27  173.690002
# 898 2023-07-28  174.479996
#
# [899 rows x 2 columns]

# %%
# treinando o modelo

modelo = Prophet(weekly_seasonality=True,
                 yearly_seasonality=True,
                 daily_seasonality=False)

modelo.add_country_holidays(country_name='US')

modelo.fit(dados_prophet_treino)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjc1obwwt/w09boini.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpjc1obwwt/ixflppgt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=87406', 'data', 'file=/tmp/tmpjc1obwwt/w09boini.json', 'init=/tmp/tmpjc1obwwt/ixflppgt.json', 'output', 'file=/tmp/tmpjc1obwwt/prophet_model86d499oy/prophet_model-20240515230823.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:08:23 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:08:24 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
# criar datas para previsao ate o final de 2023

futuro = modelo.make_future_dataframe(periods=150)
previsao = modelo.predict(futuro)

# %%
# plotagem dos dados de treino, teste e previsao

plt.figure(figsize=(14,8))
plt.plot(dados_treino['Date'], dados_treino['Close'], label='Dados de Treino', color='blue')
plt.plot(dados_teste['Date'], dados_teste['Close'], label='Dados Reais (Teste)', color='green')
plt.plot(previsao['ds'], previsao['yhat'], label='Previsão', color='orange', linestyle='--')

# legendas
plt.axvline(dados_treino['Date'].max(), color='red', linestyle='--', label='Início de Previsão')
plt.xlabel('Data')
plt.ylabel('Preço de Fechamento')
plt.title('Previsão de Preço de Fechamento vs Dados Reais')
plt.legend()
plt.show()
